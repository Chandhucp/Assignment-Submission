# %%
age = float(input("age of the brother : "))
if age<0:
    print("this cannot be true")
elif age==0:
    print("corresponds to zero human years")
elif age ==1:
    print("age is approx 4 ur elder brother years")
else:
    human=age+4
    print("corresponds to "+str(human)+" ur brothers years!!!")
# Out:
# age of the brother : 22
# corresponds to 26.0 ur brothers years!!!
